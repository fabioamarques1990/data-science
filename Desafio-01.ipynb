# %%
#Data Set Nintendo

import pandas as pd

url ='C:\Users\fabio_zph9j2v\OneDrive\Documentos\Coderhouse\data-science\\Video_Games.csv'
df = pd.read_csv(url, index_col=0)
df.head()
# Out:
#                          Platform  Year_of_Release         Genre Publisher  \
# Name
# Wii Sports                    Wii           2006.0        Sports  Nintendo
# Super Mario Bros.             NES           1985.0      Platform  Nintendo
# Mario Kart Wii                Wii           2008.0        Racing  Nintendo
# Wii Sports Resort             Wii           2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.36     28.96      3.77         8.45
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.68     12.76      3.79         3.29
# Wii Sports Resort            15.61     10.93      3.28         2.95
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales  Critic_Score  Critic_Count User_Score  \
# Name
# ...

# %%
#Tamaño del df
num_filas, num_columnas = df.shape

print(f'Número de filas: {num_filas}')
print(f'Número de columnas: {num_columnas}')
# Out:
# Número de filas: 16719
# Número de columnas: 15

# %%
## Mis variables de interes:
### Platform Year_of_Release Genre Publisher NA_Sales EU_Sales JP_Sales Other_Sales Global_Sales
## Aqui seria para hacer una comparacion de ventas entre las tres regiones del mundo mas furtes en los videojuegos de Nintendo
## y encontrar la relacion entre esas ventas y el genero del juego.

# %%
#Data set FIFA

url ='C:\Users\fabio_zph9j2v\OneDrive\Documentos\Coderhouse\data-science\\fifa_ranking.csv'
dfFIFA = pd.read_csv(url, index_col=0)
dfFIFA.head()
# Out:
#      country_full country_abrv  total_points  previous_points  rank_change  \
# rank
# 1         Germany          GER           0.0               57            0
# 2           Italy          ITA           0.0               57            0
# 3     Switzerland          SUI           0.0               50            9
# 4          Sweden          SWE           0.0               55            0
# 5       Argentina          ARG           0.0               51            5
#
#       cur_year_avg  cur_year_avg_weighted  last_year_avg  \
# rank
# 1              0.0                    0.0            0.0
# 2              0.0                    0.0            0.0
# 3              0.0                    0.0            0.0
# 4              0.0                    0.0            0.0
# 5              0.0                    0.0            0.0
#
#       last_year_avg_weighted  two_year_ago_avg  two_year_ago_weighted  \
# rank
# 1                        0.0               0.0                    0.0
# ...

# %%
#Tamaño del dfFIFA
num_filas, num_columnas = dfFIFA.shape

print(f'Número de filas: {num_filas}')
print(f'Número de columnas: {num_columnas}')
# Out:
# Número de filas: 57793
# Número de columnas: 15

# %%
## Mis variables de interes:
### country_abrv total_points previous_points rank_change cur_year_avg last_year_avg two_year_ago_avg three_year_ago_avg confederation
## Aqui seria ver como varia el ranking de paises de FIFA desde hace tres anos hasta el presente y que confederaciones estan en el top con mas frecuencia.

# %%
#Data set NBA

url ='C:\Users\fabio_zph9j2v\OneDrive\Documentos\Coderhouse\data-science\\NBASeasonData.csv'
dfNBA = pd.read_csv(url, index_col=0)
dfNBA.head()
# Out:
#        Tm          Player  Age   G    MP   PER    TS%  3PAr    FTr  ORB%  ...  \
# Year                                                                      ...
# 1978  NOJ  Truck Robinson   26  82  3638  15.7  0.481   NaN  0.340   8.0  ...
# 1978  BUF     Randy Smith   29  82  3314  19.1  0.521   NaN  0.326   3.6  ...
# 1978  WSB     Elvin Hayes   32  81  3246  17.1  0.489   NaN  0.365  10.2  ...
# 1978  BOS     Dave Cowens   29  77  3215  18.6  0.533   NaN  0.233   8.0  ...
# 1978  NYK      Bob McAdoo   26  79  3182  22.0  0.567   NaN  0.412   7.8  ...
#
#       D-WORP  Adjusted WORP  Estimated Position  BBRef Pos  Age on Feb 1  \
# Year
# 1978     1.1            1.1                 3.6        4.0         26.33
# 1978    -2.3            7.4                 1.0        2.0         29.14
# 1978     3.4            6.5                 4.2        4.0         32.21
# 1978     6.1           12.5                 3.9        5.0         29.27
# ...

# %%
#Tamaño del dfFIFA
num_filas, num_columnas = dfNBA.shape

print(f'Número de filas: {num_filas}')
print(f'Número de columnas: {num_columnas}')
# Out:
# Número de filas: 17729
# Número de columnas: 108

# %%
## Mis variables de interes:
### Year Tm Player Age G MP PER TS% 3PAr FTr ORB% DRB% TRB% AST% STL% BLK% TOV% MPG Shot% Defense Offense TrueSalary Estimated_Position BBRef_Pos Age_on_Feb_1 Yrs_Experience Height Weight
## Aqui seria ver mas en detalle las estadisticas de cada jugador de la liga, a lo largo de los anos,
## ver tambien su contribucion en relacion al equipo y observar como evoluciona de temporada tras temporada.
